# %%
#qn2
import pandas as pd
data=pd.read_csv("housing.csv")
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking furnishingstatus
# 0              no             yes        2        furnished
# 1              no             yes        3        furnished
# 2              no              no        2   semi-furnished
# 3              no             yes        3        furnished
# 4              no             yes        2        furnished

# %%
#qn3(univariate Analysis)
import matplotlib.pyplot as plt
plt.plot(data['price'])

# %%
#qn3(Bivariate Analysis)
plt.bar(data['furnishingstatus'],data['price'])
plt.xlabel('furnishingstatus')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
#qn3(multivariate analysis)
import seaborn as sns
sns.pairplot(data,hue="furnishingstatus")

# %%
#qn4
data.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
#qn5
data.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# furnishingstatus    0
# dtype: int64

# %%
#qn6 [removing outlier of price]
q1=data.price.quantile(0.25)
q3=data.price.quantile(0.75)
IQR=q3-q1
print(IQR)
data=data[~((data.price<(q1-1.5*IQR))|(data.price>(q3+1.5*IQR)))]
data
sns.boxplot(data['price'])
# Out:
# 2149000.0
# D:\Anacoda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price'>

# %%
#qn6 [removing outlier of area]
q1=data['area'].quantile(0.25)
q3=data['area'].quantile(0.75)
iqr=q3-q1
print(iqr)
data=data[~((data['area']<(q1-1.5*iqr))|(data['area']>(q3+1.5*iqr)))]
sns.boxplot(data['area'])
# Out:
# 2490.0
# D:\Anacoda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='area'>

# %%
#qn6 [removing outlier of bedroom]
q1=data['bedrooms'].quantile(0.25)
q3=data['bedrooms'].quantile(0.75)
IQR=q3-q1
print(IQR)
data=data[~((data['bedrooms']<(q1-1.5*IQR))|(data['bedrooms']>(q3+1.5*IQR)))]
sns.boxplot(data['bedrooms'])
# Out:
# 1.0
# D:\Anacoda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='bedrooms'>

# %%
#qn6 [removing outlier of stories]
q1=data['stories'].quantile(0.25)
q3=data['stories'].quantile(0.75)
IQR=q3-q1
print(IQR)
data=data[~((data['stories']<(q1-1.5*IQR))|(data['stories']>(q3+1.5*IQR)))]
sns.boxplot(data['stories'])
# Out:
# 1.0
# D:\Anacoda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='stories'>

# %%
#qn6 [removing outlier of parking]
q1=data['parking'].quantile(0.25)
q3=data['parking'].quantile(0.75)
IQR=q3-q1
print(IQR)
data=data[~((data['parking']<(q1-1.5*IQR))|(data['parking']>(q3+1.5*IQR)))]
sns.boxplot(data['parking'])
# Out:
# 1.0
# D:\Anacoda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='parking'>

# %%
data.dtypes
# Out:
# price                int64
# area                 int64
# bedrooms             int64
# bathrooms            int64
# stories              int64
# mainroad            object
# guestroom           object
# basement            object
# hotwaterheating     object
# airconditioning     object
# parking              int64
# furnishingstatus    object
# mainroad_cat          int8
# dtype: object

# %%
#qn7
data=pd.read_csv('housing.csv')
data['mainroad']=data['mainroad'].astype('category')
data['mainroad']=data['mainroad'].cat.codes
data['guestroom']=data['guestroom'].astype('category')
data['guestroom']=data['guestroom'].cat.codes
data['basement']=data['basement'].astype('category')
data['basement']=data['basement'].cat.codes
data['hotwaterheating']=data['hotwaterheating'].astype('category')
data['hotwaterheating']=data['hotwaterheating'].cat.codes
data['airconditioning']=data['airconditioning'].astype('category')
data['airconditioning']=data['airconditioning'].cat.codes
data['furnishingstatus']=data['furnishingstatus'].astype('category')
data['furnishingstatus']=data['furnishingstatus'].cat.codes
data.dtypes
# Out:
# price               int64
# area                int64
# bedrooms            int64
# bathrooms           int64
# stories             int64
# mainroad             int8
# guestroom            int8
# basement             int8
# hotwaterheating      int8
# airconditioning      int8
# parking             int64
# furnishingstatus     int8
# dtype: object

# %%
#qn8
independent=data.iloc[:,1:12]
print("independent variables:\n",independent)
dependent=data['price']
print("dependent variables:\n",dependent)
# Out:
# independent variables:
#       area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0    7420         4          2        3         1          0         0
# 1    8960         4          4        4         1          0         0
# 2    9960         3          2        2         1          0         1
# 3    7500         4          2        2         1          0         1
# 4    7420         4          1        2         1          1         1
# ..    ...       ...        ...      ...       ...        ...       ...
# 540  3000         2          1        1         1          0         1
# 541  2400         3          1        1         0          0         0
# 542  3620         2          1        1         1          0         0
# 543  2910         3          1        1         0          0         0
# 544  3850         3          1        2         1          0         0
#
#      hotwaterheating  airconditioning  parking  furnishingstatus
# ...

# %%
#qn9
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(independent)
# Out:
# StandardScaler()

# %%
#qn10
training=data.sample(frac=0.8,random_state=25)
testing=data.drop(training.index)
print("training data:\n",training)
print("testing data:\n",testing)
# Out:
# training data:
#          price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 6    10150000  8580         4          3        4         1          0
# 47    7490000  6600         3          1        4         1          0
# 444   3220000  3120         3          1        2         0          0
# 325   4007500  3460         4          1        2         1          0
# 382   3570000  3150         3          1        2         1          0
# ..        ...   ...       ...        ...      ...       ...        ...
# 227   4690000  6000         2          1        1         1          0
# 272   4340000  4075         3          1        1         1          1
# 384   3570000  4500         2          1        1         0          0
# 328   3990000  4500         3          2        2         0          0
# 217   4830000  6862         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  furnishingstatus
# ...

# %%
#qn11,qn12,qn13
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.2,random_state=0)
linreg=LinearRegression()
linreg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#qn14
import numpy as np
from sklearn.metrics import mean_squared_error
y_pred=linreg.predict(x_test)
Accuracy=r2_score(y_test,y_pred)*100
print(" Accuracy of the model is %.2f" %Accuracy)
print('mean_sqrd_error is=',mean_squared_error(y_test,y_pred))
print('root_mean_squared error of is=',np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
#  Accuracy of the model is 64.33
# mean_sqrd_error is= 1027871168993.6284
# root_mean_squared error of is= 1013839.814267337
